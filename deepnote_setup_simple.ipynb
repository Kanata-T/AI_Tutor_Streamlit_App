# %% [raw]
# # 🚀 AI Tutor Streamlit App - Deepnote 簡単セットアップ
#
# このNotebookを実行すると、AI学習チューターアプリを自動的にセットアップできます。
#
# ## 📋 実行手順
# 1. **上から順番にセルを実行**
# 2. **初期化スクリプトが自動実行される**
# 3. **Streamlitアプリが起動可能になる**
#
# ## ⚠️ 事前準備
# - `.env` ファイルに `GEMINI_API_KEY` が設定されていることを確認してください
#
# ## 🆕 新機能: OCRデバッグ表示
# - AIチューターモードとチューニングモードの両方で、OCR（文字起こし）結果の詳細を確認できます
# - サイドバーの「OCR結果詳細表示」チェックボックスをオンにすると、以下の情報が表示されます：
#   - 抽出されたテキスト内容
#   - 文字数、行数、単語数の統計
#   - 日本語文字と英数字の割合
#   - 画像種別の判定結果

# %%
# 1. 環境変数の確認
import os
from pathlib import Path

print("🔍 環境変数の確認中...")

# .envファイルの存在確認
env_file = Path(".env")
if env_file.exists():
    print("✅ .envファイルが見つかりました")
    
    # .envファイルの内容を読み込み
    with open(env_file, 'r', encoding='utf-8') as f:
        env_content = f.read()
    
    if "GEMINI_API_KEY" in env_content:
        print("✅ GEMINI_API_KEYが設定されています")
    else:
        print("❌ GEMINI_API_KEYが見つかりません")
        print("📝 .envファイルに以下の形式で追加してください:")
        print("GEMINI_API_KEY=your_api_key_here")
else:
    print("❌ .envファイルが見つかりません")
    print("📝 .envファイルを作成し、以下の内容を追加してください:")
    print("GEMINI_API_KEY=your_api_key_here")

# %%
# 2. 初期化スクリプトの実行
import subprocess
import sys

print("🚀 初期化スクリプトを実行中...")
print("=" * 50)

try:
    # init_deepnote.pyを実行
    result = subprocess.run([sys.executable, "init_deepnote.py"], 
                          capture_output=True, text=True)
    
    # 標準出力を表示
    if result.stdout:
        print("📋 実行結果:")
        print(result.stdout)
    
    # エラー出力を表示
    if result.stderr:
        print("⚠️ 警告/エラー:")
        print(result.stderr)
    
    # 実行結果の判定
    if result.returncode == 0:
        print("=" * 50)
        print("✅ 初期化が正常に完了しました！")
    else:
        print("=" * 50)
        print(f"❌ 初期化でエラーが発生しました (終了コード: {result.returncode})")
        
except FileNotFoundError:
    print("❌ init_deepnote.pyファイルが見つかりません")
    print("📁 現在のディレクトリにファイルが存在することを確認してください")
except Exception as e:
    print(f"❌ 予期しないエラーが発生しました: {e}")

# %%
# 3. インストール確認
print("🔍 主要パッケージのインストール確認...")

# 必要なパッケージのリスト
required_packages = [
    'streamlit',
    'google.generativeai',
    'cv2',
    'pytesseract',
    'PIL',
    'pandas',
    'numpy'
]

installed_packages = []
missing_packages = []

for package in required_packages:
    try:
        if package == 'cv2':
            import cv2
            installed_packages.append(f"opencv-python: {cv2.__version__}")
        elif package == 'google.generativeai':
            import google.generativeai as genai
            installed_packages.append("google-generativeai: インストール済み")
        elif package == 'PIL':
            from PIL import Image
            installed_packages.append(f"Pillow: {Image.__version__}")
        else:
            module = __import__(package)
            version = getattr(module, '__version__', 'バージョン不明')
            installed_packages.append(f"{package}: {version}")
    except ImportError:
        missing_packages.append(package)

print("\n✅ インストール済みパッケージ:")
for pkg in installed_packages:
    print(f"  • {pkg}")

if missing_packages:
    print("\n❌ 不足しているパッケージ:")
    for pkg in missing_packages:
        print(f"  • {pkg}")
else:
    print("\n🎉 すべての必要なパッケージがインストールされています！")

# %%
# 4. 最終確認とテスト
print("🧪 最終動作テスト...")

# .envファイルから環境変数を読み込むテスト
try:
    from dotenv import load_dotenv
    load_dotenv()
    
    gemini_key = os.getenv('GEMINI_API_KEY')
    if gemini_key:
        print("✅ 環境変数の読み込み: 成功")
        print(f"   GEMINI_API_KEY: {'*' * (len(gemini_key) - 4) + gemini_key[-4:] if len(gemini_key) > 4 else '設定済み'}")
    else:
        print("❌ 環境変数の読み込み: GEMINI_API_KEYが見つかりません")
except ImportError:
    print("⚠️ python-dotenvがインストールされていません（オプション）")
except Exception as e:
    print(f"❌ 環境変数読み込みエラー: {e}")

# OpenCVの動作テスト
try:
    import cv2
    print("✅ OpenCV: 正常に動作")
except Exception as e:
    print(f"❌ OpenCVエラー: {e}")

# Streamlitの動作テスト
try:
    import streamlit as st
    print("✅ Streamlit: 正常に動作")
except Exception as e:
    print(f"❌ Streamlitエラー: {e}")

print("\n" + "=" * 50)
print("🎉 セットアップ完了！")
print("📱 Streamlitアプリを起動する準備ができました")
print("\n🆕 新機能: OCRデバッグ表示")
print("   - サイドバーの「OCR結果詳細表示」で文字起こし結果を確認できます")
print("   - 文字数、行数、言語分析などの詳細情報も表示されます")
print("=" * 50)

# %% [raw]
# ## 🎯 次のステップ
#
# セットアップが完了したら、以下の方法でStreamlitアプリを起動できます：
#
# ### 方法1: Deepnoteネイティブサポート（推奨）
# 1. `app_deepnote.py` ファイルを開く
# 2. Deepnoteが自動的にStreamlitアプリとして認識
# 3. 「Deploy」ボタンをクリックして起動
#
# ### 方法2: ターミナルから起動
# ```bash
# streamlit run app_deepnote.py
# ```
#
# ### 方法3: 通常のStreamlitアプリとして起動
# ```bash
# streamlit run app.py
# ```
#
# ## 🔧 OCRデバッグ機能の使い方
#
# ### AIチューターモード
# 1. 画像をアップロードして質問を送信
# 2. サイドバーの「OCR結果詳細表示 (文字起こし結果)」をチェック
# 3. 「OCR結果詳細」エクスパンダーで以下を確認：
#    - 抽出されたテキスト内容
#    - 文字数、行数、単語数の統計
#    - 日本語文字と英数字の割合分析
#    - 画像種別の判定結果
#
# ### 画像処理チューニングモード
# 1. 画像をアップロードして処理を実行
# 2. サイドバーの「OCR結果詳細表示 (チューニングモード)」をチェック
# 3. OCR処理結果の詳細を確認
#
# ## 🔧 トラブルシューティング
#
# - **OpenCVエラー**が発生した場合: 上記の初期化スクリプトが自動的に解決します
# - **APIキーエラー**が発生した場合: `.env`ファイルの設定を確認してください
# - **OCR結果が表示されない**: 画像処理が完了してからデバッグ表示をオンにしてください
# - **その他のエラー**: `DEEPNOTE_NATIVE_GUIDE.md` を参照してください

# %% [raw]
# # 🚀 AI Tutor Streamlit App - Deepnote 簡単セットアップ
#
# このNotebookを実行すると、AI学習チューターアプリを自動的にセットアップできます。
#
# ## 📋 実行手順
# 1. **上から順番にセルを実行**
# 2. **初期化スクリプトが自動実行される**
# 3. **Streamlitアプリが起動可能になる**
#
# ## ⚠️ 事前準備
# - `.env` ファイルに `GEMINI_API_KEY` が設定されていることを確認してください

# %%
# 1. 環境変数の確認
import os
from pathlib import Path

print("🔍 環境変数の確認中...")

# .envファイルの存在確認
env_file = Path(".env")
if env_file.exists():
    print("✅ .envファイルが見つかりました")
    
    # .envファイルの内容を読み込み
    with open(env_file, 'r', encoding='utf-8') as f:
        env_content = f.read()
    
    if "GEMINI_API_KEY" in env_content:
        print("✅ GEMINI_API_KEYが設定されています")
    else:
        print("❌ GEMINI_API_KEYが見つかりません")
        print("📝 .envファイルに以下の形式で追加してください:")
        print("GEMINI_API_KEY=your_api_key_here")
else:
    print("❌ .envファイルが見つかりません")
    print("📝 .envファイルを作成し、以下の内容を追加してください:")
    print("GEMINI_API_KEY=your_api_key_here")

# %%
# 2. 初期化スクリプトの実行
import subprocess
import sys

print("🚀 初期化スクリプトを実行中...")
print("=" * 50)

try:
    # init_deepnote.pyを実行
    result = subprocess.run([sys.executable, "init_deepnote.py"], 
                          capture_output=True, text=True)
    
    # 標準出力を表示
    if result.stdout:
        print("📋 実行結果:")
        print(result.stdout)
    
    # エラー出力を表示
    if result.stderr:
        print("⚠️ 警告/エラー:")
        print(result.stderr)
    
    # 実行結果の判定
    if result.returncode == 0:
        print("=" * 50)
        print("✅ 初期化が正常に完了しました！")
    else:
        print("=" * 50)
        print(f"❌ 初期化でエラーが発生しました (終了コード: {result.returncode})")
        
except FileNotFoundError:
    print("❌ init_deepnote.pyファイルが見つかりません")
    print("📁 現在のディレクトリにファイルが存在することを確認してください")
except Exception as e:
    print(f"❌ 予期しないエラーが発生しました: {e}")

# %%
# 3. インストール確認
print("🔍 主要パッケージのインストール確認...")

# 必要なパッケージのリスト
required_packages = [
    'streamlit',
    'google.generativeai',
    'cv2',
    'pytesseract',
    'PIL',
    'pandas',
    'numpy'
]

installed_packages = []
missing_packages = []

for package in required_packages:
    try:
        if package == 'cv2':
            import cv2
            installed_packages.append(f"opencv-python: {cv2.__version__}")
        elif package == 'google.generativeai':
            import google.generativeai as genai
            installed_packages.append("google-generativeai: インストール済み")
        elif package == 'PIL':
            from PIL import Image
            installed_packages.append(f"Pillow: {Image.__version__}")
        else:
            module = __import__(package)
            version = getattr(module, '__version__', 'バージョン不明')
            installed_packages.append(f"{package}: {version}")
    except ImportError:
        missing_packages.append(package)

print("\n✅ インストール済みパッケージ:")
for pkg in installed_packages:
    print(f"  • {pkg}")

if missing_packages:
    print("\n❌ 不足しているパッケージ:")
    for pkg in missing_packages:
        print(f"  • {pkg}")
else:
    print("\n🎉 すべての必要なパッケージがインストールされています！")

# %% [raw]
# ## 🎯 次のステップ
#
# セットアップが完了したら、以下の方法でStreamlitアプリを起動できます：
#
# ### 方法1: Deepnoteネイティブサポート（推奨）
# 1. `app_deepnote.py` ファイルを開く
# 2. Deepnoteが自動的にStreamlitアプリとして認識
# 3. 「Deploy」ボタンをクリックして起動
#
# ### 方法2: ターミナルから起動
# ```bash
# streamlit run app_deepnote.py
# ```
#
# ### 方法3: 通常のStreamlitアプリとして起動
# ```bash
# streamlit run app.py
# ```
#
# ## 🔧 トラブルシューティング
#
# - **OpenCVエラー**が発生した場合: 上記の初期化スクリプトが自動的に解決します
# - **APIキーエラー**が発生した場合: `.env`ファイルの設定を確認してください
# - **その他のエラー**: `DEEPNOTE_NATIVE_GUIDE.md` を参照してください

# %%
# 4. 最終確認とテスト
print("🧪 最終動作テスト...")

# .envファイルから環境変数を読み込むテスト
try:
    from dotenv import load_dotenv
    load_dotenv()
    
    gemini_key = os.getenv('GEMINI_API_KEY')
    if gemini_key:
        print("✅ 環境変数の読み込み: 成功")
        print(f"   GEMINI_API_KEY: {'*' * (len(gemini_key) - 4) + gemini_key[-4:] if len(gemini_key) > 4 else '設定済み'}")
    else:
        print("❌ 環境変数の読み込み: GEMINI_API_KEYが見つかりません")
except ImportError:
    print("⚠️ python-dotenvがインストールされていません（オプション）")
except Exception as e:
    print(f"❌ 環境変数読み込みエラー: {e}")

# OpenCVの動作テスト
try:
    import cv2
    print("✅ OpenCV: 正常に動作")
except Exception as e:
    print(f"❌ OpenCVエラー: {e}")

# Streamlitの動作テスト
try:
    import streamlit as st
    print("✅ Streamlit: 正常に動作")
except Exception as e:
    print(f"❌ Streamlitエラー: {e}")

print("\n" + "=" * 50)
print("🎉 セットアップ完了！")
print("📱 Streamlitアプリを起動する準備ができました")
print("=" * 50)

# %% [raw]
# # 🚀 AI Tutor Streamlit App - Deepnote 簡単セットアップ
#
# このNotebookを実行するだけで、AI学習チューターアプリの環境が自動的にセットアップされます。
#
# ## 📋 実行内容
# - ✅ システムライブラリの自動インストール
# - ✅ Python依存関係の自動インストール
# - ✅ OpenCV-headless版の設定
# - ✅ Tesseract OCRの設定
# - ✅ 環境変数ファイルの作成
#
# ## 🎯 使用方法
# 1. 下のセルを実行してください
# 2. 完了後、GEMINI_API_KEYを設定してください
# 3. Streamlitアプリをデプロイしてください
